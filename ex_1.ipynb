# %% [markdown]
# <a href="https://colab.research.google.com/github/YellowDuck103/Repo/blob/main/ex_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
y=np.linspace(3, 50, 2000)
k1=1
k2=3
plt.plot(y, np.cos(k1*x))
plt.plot(y, np.cos(k2*x))
